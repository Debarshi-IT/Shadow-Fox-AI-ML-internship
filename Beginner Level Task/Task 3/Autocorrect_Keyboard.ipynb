# %%
pip install nltk numpy

# %%
import nltk
from nltk.util import ngrams
from collections import defaultdict, Counter
import random

nltk.download('punkt')

class NGramModel:
    def __init__(self, n=3):
        self.n = n
        self.ngram_counts = defaultdict(Counter)
        self.context_counts = Counter()

    def train(self, text):
        tokens = nltk.word_tokenize(text.lower())

        for i in range(len(tokens) - self.n + 1):
            ngram = tuple(tokens[i:i+self.n])
            context = ngram[:-1]
            word = ngram[-1]

            self.ngram_counts[context][word] += 1
            self.context_counts[context] += 1

    def predict(self, text, top_k=3):
        tokens = nltk.word_tokenize(text.lower())
        context = tuple(tokens[-(self.n-1):])

        if context in self.ngram_counts:
            predictions = self.ngram_counts[context]
            return predictions.most_common(top_k)
        else:
            return ["No prediction found"]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from collections import defaultdict, Counter

class NGramModel:
    def __init__(self, n=3):
        self.n = n
        self.ngram_counts = defaultdict(Counter)

    def train(self, text):
        tokens = text.lower().split()

        for i in range(len(tokens) - self.n + 1):
            ngram = tuple(tokens[i:i+self.n])
            context = ngram[:-1]
            word = ngram[-1]
            self.ngram_counts[context][word] += 1

    def predict(self, text, top_k=3):
        tokens = text.lower().split()
        context = tuple(tokens[-(self.n-1):])

        if context in self.ngram_counts:
            return self.ngram_counts[context].most_common(top_k)
        else:
            return ["No prediction found"]

# %%
sample_text = """
I love machine learning.
I love deep learning.
Machine learning is powerful.
Deep learning is part of machine learning.
"""

model = NGramModel(n=3)
model.train(sample_text)

print(model.predict("I love"))
# Out:
# [('machine', 1), ('deep', 1)]

# %%
def edit_distance(word1, word2):
    m, n = len(word1), len(word2)
    dp = [[0]*(n+1) for _ in range(m+1)]

    for i in range(m+1):
        dp[i][0] = i
    for j in range(n+1):
        dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = 0 if word1[i-1] == word2[j-1] else 1
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
    return dp[m][n]

# %%
def autocorrect(word, vocabulary):
    min_dist = float('inf')
    best_match = word

    for vocab_word in vocabulary:
        dist = edit_distance(word, vocab_word)
        if dist < min_dist:
            min_dist = dist
            best_match = vocab_word

    return best_match

# %%
pip install tensorflow

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

text = """
I love machine learning
I love deep learning
Machine learning is amazing
Deep learning is powerful
"""

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

input_sequences = []

for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

max_seq_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

model = Sequential([
    Embedding(total_words, 64, input_length=max_seq_len-1),
    LSTM(100),
    Dense(total_words, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.1667 - loss: 2.1967
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1667 - loss: 2.1897
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.2500 - loss: 2.1827
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3333 - loss: 2.1755
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3333 - loss: 2.1682
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3333 - loss: 2.1605
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3333 - loss: 2.1524
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3333 - loss: 2.1439
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.3333 - loss: 2.1347
# Epoch 10/200
# ...

# %%
def keyboard_predict(user_input, model):
    words = user_input.lower().split()

    # Autocorrect last word
    if words:
        last_word = words[-1]
        corrected_word = autocorrect(last_word, model.vocabulary)
        words[-1] = corrected_word

    # Take last (n-1) words
    if len(words) >= model.n - 1:
        context_words = words[-(model.n - 1):]
    else:
        return []

    # Get predictions
    predictions = model.predict(context_words, top_k=3)

    return predictions

# %%
from collections import defaultdict, Counter

class NGramModel:
    def __init__(self, n=3):
        self.n = n
        self.ngram_counts = defaultdict(Counter)
        self.vocabulary = set()   # ✅ ADD THIS

    def train(self, text):
        tokens = text.lower().split()

        # ✅ Store vocabulary
        self.vocabulary.update(tokens)

        for i in range(len(tokens) - self.n + 1):
            ngram = tuple(tokens[i:i+self.n])
            context = ngram[:-1]
            word = ngram[-1]
            self.ngram_counts[context][word] += 1

    def predict(self, context_words, top_k=3):
        context = tuple(context_words)
        if context in self.ngram_counts:
            return self.ngram_counts[context].most_common(top_k)
        return []

# %%
sample_text = """
i love machine learning
i love deep learning
machine learning is powerful
deep learning is part of machine learning
"""

model = NGramModel(n=3)
model.train(sample_text)

# %%
while True:
    user_text = input("Type something: ")
    suggestions = keyboard_predict(user_text, model)
    print("Suggestions:", suggestions)
# Out:
# Suggestions: [('learning', 1)]
